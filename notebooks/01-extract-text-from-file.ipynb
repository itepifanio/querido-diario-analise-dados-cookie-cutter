# %%
from pathlib import Path
import os, re
from querido_diario_toolbox import Gazette

# %%
os.chdir('..')

# %%
ROOT = Path(os.path.abspath('.'))
DATA = ROOT / 'samples'

# %%
gazette_pdf = '825f0a49648db4d88e539c7643dfdb113dbfa94d.pdf'

# %%
actual_gazette = os.path.join(DATA, gazette_pdf)

# %%
gazette = Gazette(
    filepath=actual_gazette,
    apache_tika_jar= f'{ROOT}/dependencies/tika-app-1.24.1.jar',
    content=None
)

# %%
gazette.extract_content()
gazette.filepath
# Out:
# '/home/italoepifanio/openSource/test-querido-diario-toolbox/samples/825f0a49648db4d88e539c7643dfdb113dbfa94d.txt'

# %%
gazette.load_content()
gazette.content
# Out:
# '\nIMPRENSA OFICIAL DO MUNICÍPIO DE PAU DOS FERROS/RN  \n\n \n\nDIÁRIO OFICIAL \n    DO MUNICÍPIO \n\nLei Municipal n° 901, de 02 de julho de 2002 \n\n \n\n \n\n \n\nANO XIX – N° 3056 – PAU DOS FERROS/RN, sexta-feira, 08 de outubro de 2021 \n\n \n\nI PDF KIDS: Prefeitura irá celebrar Dia das Crianças proporcionando um \n\nuniverso de diversões na praça de eventos      \n\nCom a proximidade do Dia das Crianças, a \nPrefeitura de Pau dos Ferros realizará uma \nprogramação especial em comemoração à data, \nlançando o "I PDF KIDS", que ocorrerá na \npróxima terça-feira (12), das 17h às 20h, na Praça \nde Eventos Nossa Senhora da Conceição, com \nações gratuitas e abertas ao público. \n \nCom uma programação recheada de experiências \nlúdicas e brincadeiras que têm o intuito de \nproporcionar um momento de lazer, diversão e \nfortalecer o vínculo familiar e comunitário. O I PDF \nKIDS será também um momento de acolhimento, \nbrincadeiras com pula-pula, música, distribuição \nde lanche, pi
# ...
